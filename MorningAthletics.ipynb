# %% [markdown]
# <a href="https://colab.research.google.com/github/LIPPIE-LOUT/mpepeapi/blob/master/MorningAthletics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets/world-athletics_all-time-top-lists.csv')

# %%
df.head()
# Out:
#    all_time_rank  results_score                 event                category  \
# 0            1.0         1382.0  Women's Discus Throw  Outdoor Senior - Women
# 1            2.0         1372.0      Women's Shot Put  Outdoor Senior - Women
# 2            3.0         1371.0      Women's Shot Put  Outdoor Senior - Women
# 3            4.0         1367.0      Women's Shot Put  Outdoor Senior - Women
# 4            5.0         1366.0      Women's Shot Put  Outdoor Senior - Women
#
#    event_rank   mark          competitor  nat date_of_birth  pos  ...  \
# 0           1   76.8    Gabriele REINSCH  GDR    1963-09-23  1.0  ...
# 1           1  22.63  Natalya LISOVSKAYA  URS    1962-07-16  1.0  ...
# 2           2   22.6  Natalya LISOVSKAYA  URS    1962-07-16  NaN  ...
# 3           3  22.55  Natalya LISOVSKAYA  URS    1962-07-16  1.0  ...
# 4           4  22.53  Natalya LISOVSKAYA  URS    1962-07-16  1.0  ...
#
# ...

# %%
df.shape
# Out:
# (488643, 21)

# %%
df.duplicated().sum()
# Out:
# 86

# %%
df[df.duplicated()]
# Out:
#         all_time_rank  results_score                     event  \
# 5563           5488.0         1246.0        Men's Hammer Throw
# 9017           8966.0         1237.0        Men's Hammer Throw
# 22209         22041.0         1218.0        Men's Hammer Throw
# 23117         23052.0         1217.0            Men's Shot Put
# 30387         28951.0         1212.0        Men's Hammer Throw
# ...               ...            ...                       ...
# 479383            NaN         1003.0       Men's 5km Road Race
# 479438            NaN         1003.0       Men's 5km Road Race
# 479528            NaN         1003.0      Women's Hammer Throw
# 479823            NaN         1000.0       Men's 5km Road Race
# 487984            NaN            NaN  Men's 60mH indoor (0.99)
#
#                     category  event_rank   mark              competitor  nat  \
# 5563    Outdoor Senior - Men         117  82.78      Andrey ABDUVALIYEV  TJK
# ...

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(subset= "date_of_birth").sum()
# Out:
# 472897

# %%
len(df["event"].unique())
# Out:
# 171

# %%
df["event"].value_counts(normalize=True)
# Out:
# event
# Women's Hammer Throw           0.026318
# Women's 100m                   0.024724
# Women's 200m                   0.024466
# Women's 3000mSC                0.022908
# Men's 100m                     0.022798
#                                  ...
# Women's 4x800m indoor          0.000059
# Mixed 2x2x400m                 0.000055
# Men's 4x800m indoor            0.000045
# Women's Mile Road Race         0.000043
# Mixed Shuttle Hurdles Relay    0.000027
# Name: proportion, Length: 171, dtype: float64

# %%
event_per_category = df.groupby("all_time_rank")["event_type"].sum().sort_values(ascending=False)
event_per_category.head()
# Out:
# all_time_rank
# 228162.0    throwsthrowsthrowsthrowsthrowsthrowsthrowsthro...
# 1994.0      throwsthrowsthrowsthrowsthrowsthrowsthrowsmidd...
# 101.0         throwsthrowsthrowsthrowsthrowsthrowsthrowsjumps
# 722.0       throwsthrowsthrowsthrowsthrowsthrowssprintsspr...
# 749.0       throwsthrowsthrowsthrowsthrowsthrowsjumpsthrow...
# Name: event_type, dtype: object

# %%
df[df["nat"] == "KEN"].head()
# Out:
#      all_time_rank  results_score           event              category  \
# 139          140.0         1312.0  Men's Marathon  Outdoor Senior - Men
# 151          150.0         1311.0   Men's 4x1500m  Outdoor Senior - Men
# 196          188.0         1307.0  Men's Marathon  Outdoor Senior - Men
# 246          243.0         1303.0  Men's Marathon  Outdoor Senior - Men
# 280          272.0         1301.0      Men's 800m  Outdoor Senior - Men
#
#      event_rank      mark      competitor  nat date_of_birth pos  ...  \
# 139           1   2:01:09  Eliud KIPCHOGE  KEN    1984-11-05   1  ...
# 151           1  14:22.22           Kenya  KEN           NaN   1  ...
# 196           2   2:01:25   Kelvin KIPTUM  KEN    1999-12-02   1  ...
# 246           3   2:01:39  Eliud KIPCHOGE  KEN    1984-11-05   1  ...
# 280           1   1:40.91   David RUDISHA  KEN    1988-12-17   1  ...
#
#                                  venue   age  wind  mark_details  \
# ...

# %%
track = df[df["event_type"].isin(["middle-long", "sprints", "hurdles", "road-running", "race-walks", "relays"])]
track.head()
# Out:
#     all_time_rank  results_score        event              category  \
# 12           13.0         1356.0   Men's 100m  Outdoor Senior - Men
# 18           19.0         1352.0   Men's 200m  Outdoor Senior - Men
# 27           25.0         1341.0  Men's 400mH  Outdoor Senior - Men
# 28           29.0         1339.0   Men's 200m  Outdoor Senior - Men
# 32           30.0         1338.0   Men's 200m  Outdoor Senior - Men
#
#     event_rank   mark       competitor  nat date_of_birth pos  ...  \
# 12           1   9.58       Usain BOLT  JAM    1986-08-21   1  ...
# 18           1  19.19       Usain BOLT  JAM    1986-08-21   1  ...
# 27           1  45.94  Karsten WARHOLM  NOR    1996-02-28   1  ...
# 28           2  19.26      Yohan BLAKE  JAM    1989-12-26   1  ...
# 32           3   19.3       Usain BOLT  JAM    1986-08-21   1  ...
#
#                                 venue   age  wind  mark_details year_of_birth  \
# ...

# %%
df["event_type"].value_counts()
# Out:
# event_type
# middle-long        117194
# sprints             96488
# jumps               84293
# throws              76979
# hurdles             54224
# road-running        25105
# race-walks          24621
# relays               5596
# combined-events      4057
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 488557 entries, 0 to 488642
# Data columns (total 21 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   all_time_rank  365813 non-null  float64
#  1   results_score  484649 non-null  float64
#  2   event          488557 non-null  object
#  3   category       488557 non-null  object
#  4   event_rank     488557 non-null  int64
#  5   mark           488557 non-null  object
#  6   competitor     488557 non-null  object
#  7   nat            488557 non-null  object
#  8   date_of_birth  477196 non-null  object
#  9   pos            485322 non-null  object
#  10  date           488557 non-null  object
#  11  venue          488557 non-null  object
#  12  age            477196 non-null  float64
#  13  wind           81393 non-null   float64
#  14  mark_details   11239 non-null   object
#  15  year_of_birth  480369 non-null  float64
#  16  event_name     488557 non-null  object
# ...

# %%
unique_
